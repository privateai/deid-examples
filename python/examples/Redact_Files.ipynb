# %% [markdown]
# # Install Dependencies

# %%
# %pip install privateai_client
# Out:
# Requirement already satisfied: privateai_client in /opt/miniconda3/envs/python_310/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: requests~=2.31.0 in /opt/miniconda3/envs/python_310/lib/python3.10/site-packages (from privateai_client) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/miniconda3/envs/python_310/lib/python3.10/site-packages (from requests~=2.31.0->privateai_client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/envs/python_310/lib/python3.10/site-packages (from requests~=2.31.0->privateai_client) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/python_310/lib/python3.10/site-packages (from requests~=2.31.0->privateai_client) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/envs/python_310/lib/python3.10/site-packages (from requests~=2.31.0->privateai_client) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Set up Private AI Client
# Start a container in an environment available to the Internet, and update the host, port, and protocol details

# %%
from privateai_client import PAIClient
from privateai_client.objects import request_objects
from IPython.display import Audio, display, Markdown
import base64
import json
import os
import requests

client = PAIClient(url="https://api.private-ai.com/deid")

# Replace <YOUR_API_KEY> with your API Key. Get a free demo API key here: https://portal.private-ai.com/
client.add_api_key(api_key="<YOUR_API_KEY>")

print(f'Able to access Private AI container: {client.ping()}')
# Out:
# Able to access Private AI container: True

# %% [markdown]
# # Process Audio Files

# %%
# Path to open the original audio file
input_audio_file_path = 'Original_Files/Medical-Report-Audio-Unredacted.mp3' 

with open(input_audio_file_path, 'rb') as input_file:
    file_data = base64.b64encode(input_file.read()).decode()

# Make a request call
response = client.process_files_base64(
    request_object={
        'file': {
            'data': file_data,
            'content_type': 'audio/mp3'
        }
    }
)

# Path to Save the redacted audio output file
output_audio_file_path = 'Redacted_Files/Medical-Report-Audio-redacted.mp3'  

with open(output_audio_file_path, 'wb') as redacted_mp3:
  redacted_mp3.write(base64.b64decode(response.processed_file))

# Display the Audio files in the player
display(Markdown('**Original Audio:**'))
display(Audio(input_audio_file_path))

display(Markdown('**Redacted Audio:**'))
display(Audio(output_audio_file_path))

print('***** PROCESSED TEXT *****')
print(response.processed_text)
# Out:
# **Original Audio:**
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# **Redacted Audio:**
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# ***** PROCESSED TEXT *****
#  Good morning. This is [NAME_MEDICAL_PROFESSIONAL_1] from the [ORGANIZATION_MEDICAL_FACILITY_1]. Am I speaking with Mr. [NAME_1]? Good morning. Yes, this is [NAME_GIVEN_1]. Hi [NAME_GIVEN_1]. I have your [MEDICAL_PROCESS_1] results here from your test back on the [DATE_1]. We did detect some abnormalities, which may be linked to the seizures you've experienced, but I'd like to do some more testing. So I'll need to make another appointment? Yes, we'll arrange that. First, I need to ask you a few things. Alright, sure. Have you ever had [CONDITION_1]? No, I don't think so. Just headaches sometimes. Any panic attacks or hyperventilation? No, never. Good. Okay. You mentioned that there were some family history of seizures. Your mother? Yes, my mother also had seizures, I think three different times when she was in her [AGE_1].

# %% [markdown]
# # Process DOCX

# %%
with open('Original_Files/PAI_SYNTH_EN_doctor-note.doc', 'rb') as input_file:
    file_data = base64.b64encode(input_file.read()).decode()

response = client.process_files_base64(
    request_object={
        'file': {
            'data': file_data,
            'content_type': 'application/msword'
        }
    }
)

print('***** PROCESSED TEXT *****')
print(response.processed_text)
print('***** REDACTED TEXT *****')
print(json.dumps(response.entities, indent=2))

with open('Redacted_Files/PAI_SYNTH_EN_doctor-note_redacted.doc', 'wb') as redacted_docx:
  redacted_docx.write(base64.b64decode(response.processed_file))
# Out:
# ***** PROCESSED TEXT *****
#
#
#
#  [LANGUAGE_1]-[LANGUAGE_2]
#
#  2
#
#
#  [ORGANIZATION_MEDICAL_FACILITY_1]
#  [LOCATION_ADDRESS_STREET_1]
#  [LOCATION_ADDRESS_STREET_2]
#   [LOCATION_ADDRESS_STREET_3]
#  [LOCATION_ADDRESS_1]
#  [LOCATION_ZIP_1]
#  FROM THE DESK OF
#  [NAME_MEDICAL_PROFESSIONAL_1]
#  [DATE_1]
#  Re:
#  Mr. [NAME_1]
#  DOB:
#  [DOB_1]
#  To whom it may concern:
#  Dear sir/madam,
#  The above patient would like to report confirmation that they were unable to attend their final exam on the [DATE_2]
#  [DATE_3]
#   [DATE_4] as they were feeling unwell. They attended a check-up appointment at my office on this day and were advised to take [DRUG_1] and rest at home.
#  Please do not hesitate to contact me if you need further information.
#  [NAME_MEDICAL_PROFESSIONAL_2]
#  [ORGANIZATION_MEDICAL_FACILITY_1]
# ***** REDACTED TEXT *****
# [
#   {
#     "processed_text": "LANGUAGE_1",
#     "text": "en",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 2,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 12
#     },
#     "best_label": "LANGUAGE",
#     "labels": {
#       "LANGUAGE": 0.8149
#     }
#   },
#   {
#     "processed_text": "LANGUAGE_2",
#     "text": "US",
#     "location": {
#       "stt_idx": 3,
#       "end_idx": 5,
#       "stt_idx_processed": 13,
#       "end_idx_processed": 25
#     },
#     "best_label": "LANGUAGE",
#     "labels": {
#       "LOCATION": 0.2068,
#       "LOCATION_COUNTRY": 0.2026,
#       "LANGUAGE": 0.2142
#     }
#   },
#   {
#     "processed_text": "ORGANIZATION_MEDICAL_FACILITY_1",
#     "text": "Vancouver General Hospital",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 26,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 33
#     },
#     "best_label": "ORGANIZATION_MEDICAL_FACILITY",
#     "labels": {
#       "ORGANIZATION_MEDICAL_FACILITY": 0.8178,
#       "ORGANIZATION": 0.7406,
#       "LOCATION_CITY": 0.241,
#       "LOCATION": 0.2385
#     }
#   },
#   {
#     "processed_text": "LOCATION_ADDRESS_STREET_1",
#     "text": "899 W 12",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 8,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 27
#     },
#     "best_label": "LOCATION_ADDRESS_STREET",
#     "labels": {
#       "LOCATION_ADDRESS_STREET": 0.9956,
#       "LOCATION_ADDRESS": 0.9965,
#       "LOCATION": 0.9942
#     }
#   },
#   {
#     "processed_text": "LOCATION_ADDRESS_STREET_2",
#     "text": "th",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 2,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 27
#     },
#     "best_label": "LOCATION_ADDRESS_STREET",
#     "labels": {
#       "LOCATION_ADDRESS": 0.9974,
#       "LOCATION_ADDRESS_STREET": 0.9952,
#       "LOCATION": 0.9944
#     }
#   },
#   {
#     "processed_text": "LOCATION_ADDRESS_STREET_3",
#     "text": "Ave",
#     "location": {
#       "stt_idx": 1,
#       "end_idx": 4,
#       "stt_idx_processed": 1,
#       "end_idx_processed": 28
#     },
#     "best_label": "LOCATION_ADDRESS_STREET",
#     "labels": {
#       "LOCATION_ADDRESS": 0.9975,
#       "LOCATION": 0.9952,
#       "LOCATION_ADDRESS_STREET": 0.9942
#     }
#   },
#   {
#     "processed_text": "LOCATION_ADDRESS_1",
#     "text": "Vancouver BC",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 12,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 20
#     },
#     "best_label": "LOCATION_ADDRESS",
#     "labels": {
#       "LOCATION_CITY": 0.4985,
#       "LOCATION_ADDRESS": 0.9934,
#       "LOCATION": 0.9864,
#       "LOCATION_STATE": 0.4986
#     }
#   },
#   {
#     "processed_text": "LOCATION_ZIP_1",
#     "text": "V5Z 1M9",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 7,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 16
#     },
#     "best_label": "LOCATION_ZIP",
#     "labels": {
#       "LOCATION_ZIP": 0.9955,
#       "LOCATION": 0.994,
#       "LOCATION_ADDRESS": 0.998
#     }
#   },
#   {
#     "processed_text": "NAME_MEDICAL_PROFESSIONAL_1",
#     "text": "Malik Qaadri, MD",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 16,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 29
#     },
#     "best_label": "NAME_MEDICAL_PROFESSIONAL",
#     "labels": {
#       "NAME_MEDICAL_PROFESSIONAL": 0.9951,
#       "NAME": 0.5963,
#       "NAME_GIVEN": 0.1983,
#       "NAME_FAMILY": 0.3982,
#       "OCCUPATION": 0.1987
#     }
#   },
#   {
#     "processed_text": "DATE_1",
#     "text": "17-May-2019",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 11,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 8
#     },
#     "best_label": "DATE",
#     "labels": {
#       "DATE": 0.9969
#     }
#   },
#   {
#     "processed_text": "NAME_1",
#     "text": "Tomas Pencey",
#     "location": {
#       "stt_idx": 4,
#       "end_idx": 16,
#       "stt_idx_processed": 4,
#       "end_idx_processed": 12
#     },
#     "best_label": "NAME",
#     "labels": {
#       "NAME_GIVEN": 0.2482,
#       "NAME": 0.9932,
#       "NAME_FAMILY": 0.7481
#     }
#   },
#   {
#     "processed_text": "DOB_1",
#     "text": "12-12-2001",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 7
#     },
#     "best_label": "DOB",
#     "labels": {
#       "DOB": 0.9976
#     }
#   },
#   {
#     "processed_text": "DATE_2",
#     "text": "17",
#     "location": {
#       "stt_idx": 108,
#       "end_idx": 110,
#       "stt_idx_processed": 108,
#       "end_idx_processed": 116
#     },
#     "best_label": "DATE",
#     "labels": {
#       "DATE": 0.997
#     }
#   },
#   {
#     "processed_text": "DATE_3",
#     "text": "th",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 2,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 8
#     },
#     "best_label": "DATE",
#     "labels": {
#       "DATE": 0.9973
#     }
#   },
#   {
#     "processed_text": "DATE_4",
#     "text": "of April 2019",
#     "location": {
#       "stt_idx": 1,
#       "end_idx": 14,
#       "stt_idx_processed": 1,
#       "end_idx_processed": 9
#     },
#     "best_label": "DATE",
#     "labels": {
#       "DATE": 0.9977
#     }
#   },
#   {
#     "processed_text": "DRUG_1",
#     "text": "NSAIDs",
#     "location": {
#       "stt_idx": 131,
#       "end_idx": 137,
#       "stt_idx_processed": 126,
#       "end_idx_processed": 134
#     },
#     "best_label": "DRUG",
#     "labels": {
#       "DRUG": 0.9957
#     }
#   },
#   {
#     "processed_text": "NAME_MEDICAL_PROFESSIONAL_2",
#     "text": "DR. M. QAADRI",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 13,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 29
#     },
#     "best_label": "NAME_MEDICAL_PROFESSIONAL",
#     "labels": {
#       "NAME_MEDICAL_PROFESSIONAL": 0.9992,
#       "OCCUPATION": 0.2845,
#       "NAME_GIVEN": 0.2832,
#       "NAME": 0.7095,
#       "NAME_FAMILY": 0.4259
#     }
#   },
#   {
#     "processed_text": "ORGANIZATION_MEDICAL_FACILITY_1",
#     "text": "Vancouver General Hospital",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 26,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 33
#     },
#     "best_label": "ORGANIZATION_MEDICAL_FACILITY",
#     "labels": {
#       "ORGANIZATION_MEDICAL_FACILITY": 0.9988,
#       "ORGANIZATION": 0.99,
#       "LOCATION": 0.3225,
#       "LOCATION_CITY": 0.3193
#     }
#   }
# ]

# %% [markdown]
# # Process PDF

# %%
with open('Original_Files/PAI_SYNTH_EN_medical-referral_2.pdf', 'rb') as pdf_file:
  encoded_pdf = base64.b64encode(pdf_file.read()).decode('ascii')

response = client.process_files_base64(
    request_object={
        'file': {
            'data': encoded_pdf,
            'content_type': 'application/pdf'
        }
    }
)

print('***** PROCESSED TEXT *****')
print(response.processed_text)

print('***** REDACTED TEXT *****')
print(json.dumps(response.entities, indent=2))

with open('Redacted_Files/PAI_SYNTH_EN_medical-referral_2_redacted.pdf', 'wb') as redacted_pdf:
  redacted_pdf.write(base64.b64decode(response.processed_file))
# Out:
# ***** PROCESSED TEXT *****
# Clearly Imprint Patient Identification FATHERS Name: [NAME_1] MENTAL HEALTH DOB: [DOB_1] Postal Code: [LOCATION_ADDRESS_STREET_1] Referral Form CHIP: [NUMERICAL_PII_1] [ORGANIZATION_MEDICAL_FACILITY_1] [LOCATION_ADDRESS_1] Tel: [PHONE_NUMBER_1] Tel: [PHONE_NUMBER_2] Fax: [PHONE_NUMBER_3] [DATE_1] Email: [EMAIL_ADDRESS_1].[EMAIL_ADDRESS_2] Date: YYYY / MM / DD Are telephone messages OK? DYes ONO ** PLEASE ENSURE PATIENT [OCCUPATION_1] AND [OCCUPATION_2] REFERRAL INFORMATION IS COMPLETE + PREVIOUS [OCCUPATION_3] RECORDS ARE ATTACHED ** INCOMPLETE/UNCLEAR FORMS WILL BE RETURNED Referring [OCCUPATION_2] Information Family [OCCUPATION_2] Information (if not referring [OCCUPATION_2]) Name [NAME_MEDICAL_PROFESSIONAL_1] Name : [NAME_MEDICAL_PROFESSIONAL_2] Billing # [NUMERICAL_PII_2] Address [LOCATION_ADDRESS_2] Address [LOCATION_ADDRESS_3] Phone [PHONE_NUMBER_4] Phone [PHONE_NUMBER_5] A Fax ( Fax Email Father's Demographic Data Reason for Referral (Psychiatric Concerns): Please check all that apply [CONDITION_1] Expectant Father (Partner's Due Date: disrupted skep/ imprim[INJURY_1] Father (child < [AGE_1] year old) IPerinatal loss Psychiatric History (MUST include any psychiatric reports or documents) SEE ATTACHMENT Current Medications [DRUG_1]-prev. [DRUG_2] Other Involved [OCCUPATION_4] ([OCCUPATION_5], [OCCUPATION_6], [OCCUPATION_7], [OCCUPATION_8], etc.) [OCCUPATION_9] ( referring) [ORGANIZATION_1] The Perinatal Mental Health Program will contact your patient directly to arrange an appointment. FMH Referral Form, [DATE_INTERVAL_1]
# ***** REDACTED TEXT *****
# [
#   {
#     "processed_text": "NAME_1",
#     "text": "Josephine Olaver",
#     "location": {
#       "page": 1,
#       "x0": 0.51118,
#       "x1": 0.65235,
#       "y0": 0.03179,
#       "y1": 0.05086
#     },
#     "best_label": "NAME",
#     "labels": {
#       "NAME_GIVEN": 0.3573,
#       "NAME": 0.8872,
#       "NAME_FAMILY": 0.5413
#     }
#   },
#   {
#     "processed_text": "DOB_1",
#     "text": "08-19-1971",
#     "location": {
#       "page": 1,
#       "x0": 0.51529,
#       "x1": 0.62088,
#       "y0": 0.06222,
#       "y1": 0.07811
#     },
#     "best_label": "DOB",
#     "labels": {
#       "DOB": 0.9006
#     }
#   },
#   {
#     "processed_text": "LOCATION_ADDRESS_STREET_1",
#     "text": "404-32 Maynard Avenue",
#     "location": {
#       "page": 1,
#       "x0": 0.55647,
#       "x1": 0.74206,
#       "y0": 0.09037,
#       "y1": 0.10763
#     },
#     "best_label": "LOCATION_ADDRESS_STREET",
#     "labels": {
#       "LOCATION_ADDRESS": 0.9391,
#       "LOCATION": 0.9238,
#       "LOCATION_ADDRESS_STREET": 0.9021
#     }
#   },
#   {
#     "processed_text": "NUMERICAL_PII_1",
#     "text": "2694180690-YK",
#     "location": {
#       "page": 1,
#       "x0": 0.51647,
#       "x1": 0.66647,
#       "y0": 0.12216,
#       "y1": 0.14033
#     },
#     "best_label": "NUMERICAL_PII",
#     "labels": {
#       "NUMERICAL_PII": 0.5057,
#       "HEALTHCARE_NUMBER": 0.3773
#     }
#   },
#   {
#     "processed_text": "ORGANIZATION_MEDICAL_FACILITY_1",
#     "text": "St. Joseph's Health Centre",
#     "location": {
#       "page": 1,
#       "x0": 0.04588,
#       "x1": 0.23618,
#       "y0": 0.13987,
#       "y1": 0.15213
#     },
#     "best_label": "ORGANIZATION_MEDICAL_FACILITY",
#     "labels": {
#       "ORGANIZATION_MEDICAL_FACILITY": 0.9283,
#       "ORGANIZATION": 0.8691
#     }
#   },
#   {
#     "processed_text": "LOCATION_ADDRESS_1",
#     "text": "30 The Queensway, Toronto, On, M6R 1B5",
#     "location": {
#       "page": 1,
#       "x0": 0.04529,
#       "x1": 0.33176,
#       "y0": 0.15213,
#       "y1": 0.1653
#     },
#     "best_label": "LOCATION_ADDRESS",
#     "labels": {
#       "LOCATION": 0.9092,
#       "LOCATION_ADDRESS": 0.924,
#       "LOCATION_ADDRESS_STREET": 0.2432,
#       "LOCATION_CITY": 0.0641,
#       "LOCATION_STATE": 0.0618,
#       "LOCATION_ZIP": 0.3796
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_1",
#     "text": "4168699061",
#     "location": {
#       "page": 1,
#       "x0": 0.50118,
#       "x1": 0.60882,
#       "y0": 0.15259,
#       "y1": 0.16803
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.8936
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_2",
#     "text": "(416) 530-6000 ext. 4518",
#     "location": {
#       "page": 1,
#       "x0": 0.07529,
#       "x1": 0.24971,
#       "y0": 0.16576,
#       "y1": 0.17847
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.882
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_3",
#     "text": "(416) 530-6393",
#     "location": {
#       "page": 1,
#       "x0": 0.28941,
#       "x1": 0.40706,
#       "y0": 0.1653,
#       "y1": 0.17847
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.9083
#     }
#   },
#   {
#     "processed_text": "DATE_1",
#     "text": "2024/01/05",
#     "location": {
#       "page": 1,
#       "x0": 0.17412,
#       "x1": 0.29882,
#       "y0": 0.18256,
#       "y1": 0.20391
#     },
#     "best_label": "DATE",
#     "labels": {
#       "DATE": 0.8814
#     }
#   },
#   {
#     "processed_text": "EMAIL_ADDRESS_1",
#     "text": "jolavor68@gmail",
#     "location": {
#       "page": 1,
#       "x0": 0.51647,
#       "x1": 0.69794,
#       "y0": 0.17257,
#       "y1": 0.19846
#     },
#     "best_label": "EMAIL_ADDRESS",
#     "labels": {
#       "EMAIL_ADDRESS": 0.9029
#     }
#   },
#   {
#     "processed_text": "EMAIL_ADDRESS_2",
#     "text": "com",
#     "location": {
#       "page": 1,
#       "x0": 0.51647,
#       "x1": 0.69794,
#       "y0": 0.17257,
#       "y1": 0.19846
#     },
#     "best_label": "EMAIL_ADDRESS",
#     "labels": {
#       "EMAIL_ADDRESS": 0.8968
#     }
#   },
#   {
#     "processed_text": "OCCUPATION_1",
#     "text": "DEMOGRAPHICS",
#     "location": {
#       "page": 1,
#       "x0": 0.35471,
#       "x1": 0.50912,
#       "y0": 0.26612,
#       "y1": 0.28202
#     },
#     "best_label": "OCCUPATION",
#     "labels": {
#       "OCCUPATION": 0.5563,
#       "MEDICAL_PROCESS": 0.0874
#     }
#   },
#   {
#     "processed_text": "OCCUPATION_2",
#     "text": "PHYSICIAN",
#     "location": {
#       "page": 1,
#       "x0": 0.54647,
#       "x1": 0.65265,
#       "y0": 0.26658,
#       "y1": 0.28247
#     },
#     "best_label": "OCCUPATION",
#     "labels": {
#       "OCCUPATION": 0.8411
#     }
#   },
#   {
#     "processed_text": "OCCUPATION_3",
#     "text": "PSYCHIATRIC",
#     "location": {
#       "page": 1,
#       "x0": 0.41706,
#       "x1": 0.54529,
#       "y0": 0.28474,
#       "y1": 0.30018
#     },
#     "best_label": "OCCUPATION",
#     "labels": {
#       "OCCUPATION": 0.4736
#     }
#   },
#   {
#     "processed_text": "OCCUPATION_2",
#     "text": "Physician",
#     "location": {
#       "page": 1,
#       "x0": 0.13,
#       "x1": 0.22,
#       "y0": 0.35922,
#       "y1": 0.37466
#     },
#     "best_label": "OCCUPATION",
#     "labels": {
#       "OCCUPATION": 0.8318
#     }
#   },
#   {
#     "processed_text": "OCCUPATION_2",
#     "text": "Physician",
#     "location": {
#       "page": 1,
#       "x0": 0.54765,
#       "x1": 0.63912,
#       "y0": 0.35876,
#       "y1": 0.37466
#     },
#     "best_label": "OCCUPATION",
#     "labels": {
#       "OCCUPATION": 0.5246
#     }
#   },
#   {
#     "processed_text": "OCCUPATION_2",
#     "text": "physician",
#     "location": {
#       "page": 1,
#       "x0": 0.85647,
#       "x1": 0.94529,
#       "y0": 0.35922,
#       "y1": 0.37557
#     },
#     "best_label": "OCCUPATION",
#     "labels": {
#       "OCCUPATION": 0.8053
#     }
#   },
#   {
#     "processed_text": "NAME_MEDICAL_PROFESSIONAL_1",
#     "text": "Lars Stanwyck",
#     "location": {
#       "page": 1,
#       "x0": 0.12529,
#       "x1": 0.28676,
#       "y0": 0.37875,
#       "y1": 0.39646
#     },
#     "best_label": "NAME_MEDICAL_PROFESSIONAL",
#     "labels": {
#       "NAME": 0.8979,
#       "NAME_GIVEN": 0.2164,
#       "NAME_MEDICAL_PROFESSIONAL": 0.5176,
#       "NAME_FAMILY": 0.689
#     }
#   },
#   {
#     "processed_text": "NAME_MEDICAL_PROFESSIONAL_2",
#     "text": "Bill Neclunaite",
#     "location": {
#       "page": 1,
#       "x0": 0.56353,
#       "x1": 0.70971,
#       "y0": 0.37738,
#       "y1": 0.39555
#     },
#     "best_label": "NAME_MEDICAL_PROFESSIONAL",
#     "labels": {
#       "NAME_GIVEN": 0.1729,
#       "NAME": 0.9037,
#       "NAME_MEDICAL_PROFESSIONAL": 0.428,
#       "NAME_FAMILY": 0.7461
#     }
#   },
#   {
#     "processed_text": "NUMERICAL_PII_2",
#     "text": "656381",
#     "location": {
#       "page": 1,
#       "x0": 0.12529,
#       "x1": 0.21176,
#       "y0": 0.40009,
#       "y1": 0.41826
#     },
#     "best_label": "NUMERICAL_PII",
#     "labels": {
#       "NUMERICAL_PII": 0.909
#     }
#   },
#   {
#     "processed_text": "LOCATION_ADDRESS_2",
#     "text": "15 Roncesvalles Are MOR 242",
#     "location": {
#       "page": 1,
#       "x0": 0.56353,
#       "x1": 0.83176,
#       "y0": 0.40145,
#       "y1": 0.4178
#     },
#     "best_label": "LOCATION_ADDRESS",
#     "labels": {
#       "LOCATION_ADDRESS": 0.9456,
#       "LOCATION": 0.9091,
#       "LOCATION_ADDRESS_STREET": 0.5896,
#       "LOCATION_ZIP": 0.1355
#     }
#   },
#   {
#     "processed_text": "LOCATION_ADDRESS_3",
#     "text": "30 The Queenaway FOR/ON/MOR 1B5",
#     "location": {
#       "page": 1,
#       "x0": 0.12353,
#       "x1": 0.47059,
#       "y0": 0.42371,
#       "y1": 0.44369
#     },
#     "best_label": "LOCATION_ADDRESS",
#     "labels": {
#       "LOCATION_ADDRESS": 0.9471,
#       "LOCATION": 0.8739,
#       "LOCATION_ADDRESS_STREET": 0.2786,
#       "LOCATION_STATE": 0.2457,
#       "LOCATION_ZIP": 0.2638
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_4",
#     "text": "(416) 925 6126",
#     "location": {
#       "page": 1,
#       "x0": 0.54529,
#       "x1": 0.75441,
#       "y0": 0.42461,
#       "y1": 0.44187
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.909
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_5",
#     "text": "(416) 530 6100",
#     "location": {
#       "page": 1,
#       "x0": 0.10118,
#       "x1": 0.30206,
#       "y0": 0.4455,
#       "y1": 0.46367
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.9064
#     }
#   },
#   {
#     "processed_text": "CONDITION_1",
#     "text": "generalized anxiety",
#     "location": {
#       "page": 1,
#       "x0": 0.47118,
#       "x1": 0.67706,
#       "y0": 0.58084,
#       "y1": 0.60082
#     },
#     "best_label": "CONDITION",
#     "labels": {
#       "CONDITION": 0.8933
#     }
#   },
#   {
#     "processed_text": "INJURY_1",
#     "text": "nia",
#     "location": {
#       "page": 1,
#       "x0": 0.62059,
#       "x1": 0.71882,
#       "y0": 0.60445,
#       "y1": 0.62534
#     },
#     "best_label": "INJURY",
#     "labels": {
#       "INJURY": 0.412,
#       "CONDITION": 0.2816
#     }
#   },
#   {
#     "processed_text": "AGE_1",
#     "text": "1",
#     "location": {
#       "page": 1,
#       "x0": 0.17882,
#       "x1": 0.19529,
#       "y0": 0.63351,
#       "y1": 0.64714
#     },
#     "best_label": "AGE",
#     "labels": {
#       "AGE": 0.8527
#     }
#   },
#   {
#     "processed_text": "DRUG_1",
#     "text": "Ativan",
#     "location": {
#       "page": 1,
#       "x0": 0.24647,
#       "x1": 0.41706,
#       "y0": 0.73569,
#       "y1": 0.75931
#     },
#     "best_label": "DRUG",
#     "labels": {
#       "DRUG": 0.9251
#     }
#   },
#   {
#     "processed_text": "DRUG_2",
#     "text": "Buspar",
#     "location": {
#       "page": 1,
#       "x0": 0.41235,
#       "x1": 0.50529,
#       "y0": 0.73252,
#       "y1": 0.75795
#     },
#     "best_label": "DRUG",
#     "labels": {
#       "DRUG": 0.9091
#     }
#   },
#   {
#     "processed_text": "OCCUPATION_4",
#     "text": "Mental Health Professionals",
#     "location": {
#       "page": 1,
#       "x0": 0.18,
#       "x1": 0.41735,
#       "y0": 0.7693,
#       "y1": 0.78565
#     },
#     "best_label": "OCCUPATION",
#     "labels": {
#       "OCCUPATION": 0.789
#     }
#   },
#   {
#     "processed_text": "OCCUPATION_5",
#     "text": "Psychiatrist",
#     "location": {
#       "page": 1,
#       "x0": 0.41059,
#       "x1": 0.52912,
#       "y0": 0.76839,
#       "y1": 0.7861
#     },
#     "best_label": "OCCUPATION",
#     "labels": {
#       "OCCUPATION": 0.8834
#     }
#   },
#   {
#     "processed_text": "OCCUPATION_6",
#     "text": "Social Worker",
#     "location": {
#       "page": 1,
#       "x0": 0.52176,
#       "x1": 0.65324,
#       "y0": 0.76839,
#       "y1": 0.7861
#     },
#     "best_label": "OCCUPATION",
#     "labels": {
#       "OCCUPATION": 0.8662
#     }
#   },
#   {
#     "processed_text": "OCCUPATION_7",
#     "text": "Therapist",
#     "location": {
#       "page": 1,
#       "x0": 0.64529,
#       "x1": 0.74,
#       "y0": 0.76885,
#       "y1": 0.7861
#     },
#     "best_label": "OCCUPATION",
#     "labels": {
#       "OCCUPATION": 0.8667
#     }
#   },
#   {
#     "processed_text": "OCCUPATION_8",
#     "text": "CAS",
#     "location": {
#       "page": 1,
#       "x0": 0.73235,
#       "x1": 0.78235,
#       "y0": 0.76885,
#       "y1": 0.7861
#     },
#     "best_label": "OCCUPATION",
#     "labels": {
#       "OCCUPATION": 0.5501
#     }
#   },
#   {
#     "processed_text": "OCCUPATION_9",
#     "text": "psychotherapist",
#     "location": {
#       "page": 1,
#       "x0": 0.74176,
#       "x1": 0.94706,
#       "y0": 0.78656,
#       "y1": 0.83152
#     },
#     "best_label": "OCCUPATION",
#     "labels": {
#       "OCCUPATION": 0.8879
#     }
#   },
#   {
#     "processed_text": "ORGANIZATION_1",
#     "text": "UNITY HEALTH TORONTO",
#     "location": {
#       "page": 1,
#       "x0": 0.40059,
#       "x1": 0.65559,
#       "y0": 0.87193,
#       "y1": 0.91235
#     },
#     "best_label": "ORGANIZATION",
#     "labels": {
#       "ORGANIZATION": 0.8834,
#       "ORGANIZATION_MEDICAL_FACILITY": 0.5698,
#       "LOCATION_CITY": 0.4078,
#       "LOCATION": 0.3842
#     }
#   },
#   {
#     "processed_text": "DATE_INTERVAL_1",
#     "text": "July 2020",
#     "location": {
#       "page": 1,
#       "x0": 0.53824,
#       "x1": 0.61206,
#       "y0": 0.9723,
#       "y1": 0.98592
#     },
#     "best_label": "DATE_INTERVAL",
#     "labels": {
#       "DATE_INTERVAL": 0.9284
#     }
#   }
# ]

# %% [markdown]
# # Process CSV

# %%
with open('Original_Files/HEALTHCARE_oliverjakeconnor_health-care-system-analysis-Patient_records.csv', 'rb') as csv_file:
  encoded_csv = base64.b64encode(csv_file.read()).decode('ascii')

response = client.process_files_base64(
    request_object={
        'file': {
            'data': encoded_csv,
            'content_type': 'text/csv'
        }
    }
)

print('***** PROCESSED TEXT *****')
print(response.processed_text)

print('***** REDACTED TEXT *****')
print(json.dumps(response.entities, indent=2))

with open('Redacted_Files/HEALTHCARE_oliverjakeconnor_health-care-system-analysis-Patient_records_redacted.csv', 'wb') as redacted_csv:
  redacted_csv.write(base64.b64decode(response.processed_file))
# Out:
# ***** PROCESSED TEXT *****
#
# ***** REDACTED TEXT *****
# [
#   {
#     "processed_text": "NUMERICAL_PII_1",
#     "text": "187158",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "NUMERICAL_PII",
#     "labels": {
#       "NUMERICAL_PII": 0.9117,
#       "HEALTHCARE_NUMBER": 0.409
#     }
#   },
#   {
#     "processed_text": "NAME_GIVEN_1",
#     "text": "Harbir",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 14
#     },
#     "best_label": "NAME_GIVEN",
#     "labels": {
#       "NAME": 0.9958,
#       "NAME_GIVEN": 0.9255,
#       "NAME_FAMILY": 0.1271
#     }
#   },
#   {
#     "processed_text": "GENDER_SEXUALITY_1",
#     "text": "Female",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 20
#     },
#     "best_label": "GENDER_SEXUALITY",
#     "labels": {
#       "GENDER_SEXUALITY": 0.9961
#     }
#   },
#   {
#     "processed_text": "DOB_1",
#     "text": "1924-06-30",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 7
#     },
#     "best_label": "DOB",
#     "labels": {
#       "DOB": 0.9983
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_1",
#     "text": "+91 0112009318",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 14,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 16
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.9973
#     }
#   },
#   {
#     "processed_text": "CONDITION_1",
#     "text": "Galactosemia",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 12,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 13
#     },
#     "best_label": "CONDITION",
#     "labels": {
#       "CONDITION": 0.9974
#     }
#   },
#   {
#     "processed_text": "LOCATION_CITY_1",
#     "text": "Rourkela",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 8,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "LOCATION_CITY",
#     "labels": {
#       "LOCATION_CITY": 0.9977,
#       "LOCATION": 0.9933
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_1",
#     "text": "H1001",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.9955
#     }
#   },
#   {
#     "processed_text": "NUMERICAL_PII_1",
#     "text": "112766",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "NUMERICAL_PII",
#     "labels": {
#       "NUMERICAL_PII": 0.8725,
#       "HEALTHCARE_NUMBER": 0.8021
#     }
#   },
#   {
#     "processed_text": "NAME_GIVEN_1",
#     "text": "Brahmdev",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 8,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 14
#     },
#     "best_label": "NAME_GIVEN",
#     "labels": {
#       "NAME": 0.9949,
#       "NAME_GIVEN": 0.8767,
#       "NAME_FAMILY": 0.277
#     }
#   },
#   {
#     "processed_text": "GENDER_SEXUALITY_1",
#     "text": "Female",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 20
#     },
#     "best_label": "GENDER_SEXUALITY",
#     "labels": {
#       "GENDER_SEXUALITY": 0.9963
#     }
#   },
#   {
#     "processed_text": "DOB_1",
#     "text": "1948-12-20",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 7
#     },
#     "best_label": "DOB",
#     "labels": {
#       "DOB": 0.9983
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_1",
#     "text": "+91 1727749552",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 14,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 16
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.997
#     }
#   },
#   {
#     "processed_text": "CONDITION_1",
#     "text": "Bladder cancer",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 14,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 13
#     },
#     "best_label": "CONDITION",
#     "labels": {
#       "CONDITION": 0.9972
#     }
#   },
#   {
#     "processed_text": "LOCATION_CITY_1",
#     "text": "Tiruvottiyur",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 12,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "LOCATION_CITY",
#     "labels": {
#       "LOCATION": 0.9923,
#       "LOCATION_CITY": 0.9945
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_1",
#     "text": "H1016",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.987,
#       "NUMERICAL_PII": 0.0525
#     }
#   },
#   {
#     "processed_text": "NUMERICAL_PII_1",
#     "text": "199252",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "NUMERICAL_PII",
#     "labels": {
#       "NUMERICAL_PII": 0.8722,
#       "HEALTHCARE_NUMBER": 0.4957
#     }
#   },
#   {
#     "processed_text": "NAME_GIVEN_1",
#     "text": "Ujjawal",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 7,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 14
#     },
#     "best_label": "NAME_GIVEN",
#     "labels": {
#       "NAME": 0.9942,
#       "NAME_GIVEN": 0.9049,
#       "NAME_FAMILY": 0.1107
#     }
#   },
#   {
#     "processed_text": "GENDER_SEXUALITY_1",
#     "text": "Male",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 4,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 20
#     },
#     "best_label": "GENDER_SEXUALITY",
#     "labels": {
#       "GENDER_SEXUALITY": 0.9969
#     }
#   },
#   {
#     "processed_text": "DOB_1",
#     "text": "1980-04-16",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 7
#     },
#     "best_label": "DOB",
#     "labels": {
#       "DOB": 0.998
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_1",
#     "text": "+91 8547451606",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 14,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 16
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.9971
#     }
#   },
#   {
#     "processed_text": "CONDITION_1",
#     "text": "Kidney cancer",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 13,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 13
#     },
#     "best_label": "CONDITION",
#     "labels": {
#       "CONDITION": 0.9974
#     }
#   },
#   {
#     "processed_text": "LOCATION_CITY_1",
#     "text": "Berhampur",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 9,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "LOCATION_CITY",
#     "labels": {
#       "LOCATION": 0.9936,
#       "LOCATION_CITY": 0.9949
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_1",
#     "text": "H1009",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.9918
#     }
#   },
#   {
#     "processed_text": "NUMERICAL_PII_1",
#     "text": "133424",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "NUMERICAL_PII",
#     "labels": {
#       "NUMERICAL_PII": 0.849,
#       "HEALTHCARE_NUMBER": 0.6965
#     }
#   },
#   {
#     "processed_text": "NAME_GIVEN_1",
#     "text": "Ballari",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 7,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 14
#     },
#     "best_label": "NAME_GIVEN",
#     "labels": {
#       "NAME": 0.9933,
#       "NAME_GIVEN": 0.8915,
#       "NAME_FAMILY": 0.1325
#     }
#   },
#   {
#     "processed_text": "GENDER_SEXUALITY_1",
#     "text": "Female",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 20
#     },
#     "best_label": "GENDER_SEXUALITY",
#     "labels": {
#       "GENDER_SEXUALITY": 0.9954
#     }
#   },
#   {
#     "processed_text": "DOB_1",
#     "text": "1969-09-25",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 7
#     },
#     "best_label": "DOB",
#     "labels": {
#       "DOB": 0.9981
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_1",
#     "text": "+91 0106026841",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 14,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 16
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.997
#     }
#   },
#   {
#     "processed_text": "LOCATION_CITY_1",
#     "text": "Bihar Sharif",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 12,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "LOCATION_CITY",
#     "labels": {
#       "LOCATION": 0.6471,
#       "LOCATION_CITY": 0.5626,
#       "LOCATION_STATE": 0.0873
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_1",
#     "text": "H1017",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.9818,
#       "NUMERICAL_PII": 0.2756
#     }
#   },
#   {
#     "processed_text": "NUMERICAL_PII_1",
#     "text": "172579",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "NUMERICAL_PII",
#     "labels": {
#       "NUMERICAL_PII": 0.9627,
#       "HEALTHCARE_NUMBER": 0.3117
#     }
#   },
#   {
#     "processed_text": "NAME_GIVEN_1",
#     "text": "Devnath",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 7,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 14
#     },
#     "best_label": "NAME_GIVEN",
#     "labels": {
#       "NAME": 0.9955,
#       "NAME_GIVEN": 0.9167,
#       "NAME_FAMILY": 0.0513
#     }
#   },
#   {
#     "processed_text": "GENDER_SEXUALITY_1",
#     "text": "Female",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 20
#     },
#     "best_label": "GENDER_SEXUALITY",
#     "labels": {
#       "GENDER_SEXUALITY": 0.996
#     }
#   },
#   {
#     "processed_text": "DOB_1",
#     "text": "1946-05-01",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 7
#     },
#     "best_label": "DOB",
#     "labels": {
#       "DOB": 0.9981
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_1",
#     "text": "+91 1868774631",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 14,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 16
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.9968
#     }
#   },
#   {
#     "processed_text": "CONDITION_1",
#     "text": "Food allergy",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 12,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 13
#     },
#     "best_label": "CONDITION",
#     "labels": {
#       "CONDITION": 0.9979
#     }
#   },
#   {
#     "processed_text": "LOCATION_CITY_1",
#     "text": "Bidhannagar",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 11,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "LOCATION_CITY",
#     "labels": {
#       "LOCATION_CITY": 0.9973,
#       "LOCATION": 0.9932
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_1",
#     "text": "H1019",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.9927
#     }
#   },
#   {
#     "processed_text": "NUMERICAL_PII_1",
#     "text": "171320",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "NUMERICAL_PII",
#     "labels": {
#       "NUMERICAL_PII": 0.929,
#       "HEALTHCARE_NUMBER": 0.4172
#     }
#   },
#   {
#     "processed_text": "NAME_GIVEN_1",
#     "text": "Atasi",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 14
#     },
#     "best_label": "NAME_GIVEN",
#     "labels": {
#       "NAME": 0.9946,
#       "NAME_GIVEN": 0.9273
#     }
#   },
#   {
#     "processed_text": "GENDER_SEXUALITY_1",
#     "text": "Male",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 4,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 20
#     },
#     "best_label": "GENDER_SEXUALITY",
#     "labels": {
#       "GENDER_SEXUALITY": 0.9966
#     }
#   },
#   {
#     "processed_text": "DOB_1",
#     "text": "1967-10-02",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 7
#     },
#     "best_label": "DOB",
#     "labels": {
#       "DOB": 0.9979
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_1",
#     "text": "+91 9747336855",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 14,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 16
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.9965
#     }
#   },
#   {
#     "processed_text": "CONDITION_1",
#     "text": "Whiplash",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 8,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 13
#     },
#     "best_label": "CONDITION",
#     "labels": {
#       "CONDITION": 0.9633,
#       "INJURY": 0.2777
#     }
#   },
#   {
#     "processed_text": "LOCATION_CITY_1",
#     "text": "Amravati",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 8,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "LOCATION_CITY",
#     "labels": {
#       "LOCATION": 0.9936,
#       "LOCATION_CITY": 0.9966
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_1",
#     "text": "H1013",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.9656,
#       "NUMERICAL_PII": 0.3367
#     }
#   },
#   {
#     "processed_text": "NUMERICAL_PII_1",
#     "text": "107794",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "NUMERICAL_PII",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.7807,
#       "NUMERICAL_PII": 0.7998
#     }
#   },
#   {
#     "processed_text": "NAME_GIVEN_1",
#     "text": "Manish",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 14
#     },
#     "best_label": "NAME_GIVEN",
#     "labels": {
#       "NAME": 0.9946,
#       "NAME_GIVEN": 0.9611
#     }
#   },
#   {
#     "processed_text": "GENDER_SEXUALITY_1",
#     "text": "Male",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 4,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 20
#     },
#     "best_label": "GENDER_SEXUALITY",
#     "labels": {
#       "GENDER_SEXUALITY": 0.9953
#     }
#   },
#   {
#     "processed_text": "DOB_1",
#     "text": "1967-06-06",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 7
#     },
#     "best_label": "DOB",
#     "labels": {
#       "DOB": 0.9982
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_1",
#     "text": "+91 4354294043",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 14,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 16
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.9964
#     }
#   },
#   {
#     "processed_text": "LOCATION_CITY_1",
#     "text": "Panvel",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "LOCATION_CITY",
#     "labels": {
#       "LOCATION": 0.9856,
#       "LOCATION_CITY": 0.9592
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_1",
#     "text": "H1004",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.9928
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_1",
#     "text": "130339",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.8486,
#       "NUMERICAL_PII": 0.6764
#     }
#   },
#   {
#     "processed_text": "NAME_GIVEN_1",
#     "text": "Aakar",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 14
#     },
#     "best_label": "NAME_GIVEN",
#     "labels": {
#       "NAME": 0.9946,
#       "NAME_GIVEN": 0.9335,
#       "NAME_FAMILY": 0.0572
#     }
#   },
#   {
#     "processed_text": "GENDER_SEXUALITY_1",
#     "text": "Female",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 20
#     },
#     "best_label": "GENDER_SEXUALITY",
#     "labels": {
#       "GENDER_SEXUALITY": 0.996
#     }
#   },
#   {
#     "processed_text": "DOB_1",
#     "text": "1925-03-05",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 7
#     },
#     "best_label": "DOB",
#     "labels": {
#       "DOB": 0.9982
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_1",
#     "text": "+91 2777633911",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 14,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 16
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.9969
#     }
#   },
#   {
#     "processed_text": "LOCATION_CITY_1",
#     "text": "Bihar Sharif",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 12,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "LOCATION_CITY",
#     "labels": {
#       "LOCATION": 0.6541,
#       "LOCATION_CITY": 0.646,
#       "LOCATION_STATE": 0.0584
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_2",
#     "text": "H1000",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.9655,
#       "NUMERICAL_PII": 0.0752
#     }
#   },
#   {
#     "processed_text": "NUMERICAL_PII_1",
#     "text": "110377",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "NUMERICAL_PII",
#     "labels": {
#       "NUMERICAL_PII": 0.8728,
#       "HEALTHCARE_NUMBER": 0.6848
#     }
#   },
#   {
#     "processed_text": "NAME_GIVEN_1",
#     "text": "Gurudas",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 7,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 14
#     },
#     "best_label": "NAME_GIVEN",
#     "labels": {
#       "NAME": 0.9949,
#       "NAME_GIVEN": 0.6809,
#       "NAME_FAMILY": 0.2524
#     }
#   },
#   {
#     "processed_text": "GENDER_SEXUALITY_1",
#     "text": "Male",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 4,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 20
#     },
#     "best_label": "GENDER_SEXUALITY",
#     "labels": {
#       "GENDER_SEXUALITY": 0.9969
#     }
#   },
#   {
#     "processed_text": "DOB_1",
#     "text": "1945-05-06",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 7
#     },
#     "best_label": "DOB",
#     "labels": {
#       "DOB": 0.9981
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_1",
#     "text": "+91 1232859381",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 14,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 16
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.9969
#     }
#   },
#   {
#     "processed_text": "CONDITION_1",
#     "text": "Dengue",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 13
#     },
#     "best_label": "CONDITION",
#     "labels": {
#       "CONDITION": 0.9974
#     }
#   },
#   {
#     "processed_text": "LOCATION_CITY_1",
#     "text": "Kamarhati",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 9,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "LOCATION_CITY",
#     "labels": {
#       "LOCATION": 0.9941,
#       "LOCATION_CITY": 0.9893
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_1",
#     "text": "H1001",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.9576,
#       "NUMERICAL_PII": 0.4703
#     }
#   },
#   {
#     "processed_text": "NUMERICAL_PII_1",
#     "text": "149367",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "NUMERICAL_PII",
#     "labels": {
#       "NUMERICAL_PII": 0.8657,
#       "HEALTHCARE_NUMBER": 0.6462
#     }
#   },
#   {
#     "processed_text": "GENDER_SEXUALITY_1",
#     "text": "Male",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 4,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 20
#     },
#     "best_label": "GENDER_SEXUALITY",
#     "labels": {
#       "GENDER_SEXUALITY": 0.9942
#     }
#   },
#   {
#     "processed_text": "DOB_1",
#     "text": "1925-06-12",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 7
#     },
#     "best_label": "DOB",
#     "labels": {
#       "DOB": 0.9984
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_1",
#     "text": "+91 1780763280",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 14,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 16
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.9964
#     }
#   },
#   {
#     "processed_text": "CONDITION_1",
#     "text": "Head banging",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 12,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 13
#     },
#     "best_label": "CONDITION",
#     "labels": {
#       "CONDITION": 0.9837
#     }
#   },
#   {
#     "processed_text": "LOCATION_CITY_1",
#     "text": "Bangalore",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 9,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "LOCATION_CITY",
#     "labels": {
#       "LOCATION": 0.9971,
#       "LOCATION_CITY": 0.9963
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_1",
#     "text": "H1013",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.9642,
#       "NUMERICAL_PII": 0.4266
#     }
#   },
#   {
#     "processed_text": "NUMERICAL_PII_1",
#     "text": "156168",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "NUMERICAL_PII",
#     "labels": {
#       "NUMERICAL_PII": 0.8867,
#       "HEALTHCARE_NUMBER": 0.5194,
#       "ACCOUNT_NUMBER": 0.0947
#     }
#   },
#   {
#     "processed_text": "GENDER_SEXUALITY_1",
#     "text": "Male",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 4,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 20
#     },
#     "best_label": "GENDER_SEXUALITY",
#     "labels": {
#       "GENDER_SEXUALITY": 0.9948
#     }
#   },
#   {
#     "processed_text": "DOB_1",
#     "text": "1976-02-03",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 7
#     },
#     "best_label": "DOB",
#     "labels": {
#       "DOB": 0.998
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_1",
#     "text": "+91 5586075345",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 14,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 16
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.9973
#     }
#   },
#   {
#     "processed_text": "CONDITION_1",
#     "text": "Fanconi anaemia",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 15,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 13
#     },
#     "best_label": "CONDITION",
#     "labels": {
#       "CONDITION": 0.9974
#     }
#   },
#   {
#     "processed_text": "LOCATION_CITY_1",
#     "text": "Rajkot",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "LOCATION_CITY",
#     "labels": {
#       "LOCATION_CITY": 0.9974,
#       "LOCATION": 0.9922
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_1",
#     "text": "H1004",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.9887,
#       "NUMERICAL_PII": 0.0741
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_1",
#     "text": "114241",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.8157,
#       "NUMERICAL_PII": 0.7821
#     }
#   },
#   {
#     "processed_text": "GENDER_SEXUALITY_1",
#     "text": "Female",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 20
#     },
#     "best_label": "GENDER_SEXUALITY",
#     "labels": {
#       "GENDER_SEXUALITY": 0.9945
#     }
#   },
#   {
#     "processed_text": "DOB_1",
#     "text": "1955-01-22",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 7
#     },
#     "best_label": "DOB",
#     "labels": {
#       "DOB": 0.9984
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_1",
#     "text": "+91 4146391938",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 14,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 16
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.9969
#     }
#   },
#   {
#     "processed_text": "CONDITION_1",
#     "text": "Breast cancer",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 13,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 13
#     },
#     "best_label": "CONDITION",
#     "labels": {
#       "CONDITION": 0.998
#     }
#   },
#   {
#     "processed_text": "LOCATION_CITY_1",
#     "text": "Ghaziabad",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 9,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "LOCATION_CITY",
#     "labels": {
#       "LOCATION_CITY": 0.9984,
#       "LOCATION": 0.9939
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_2",
#     "text": "H1015",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.9482,
#       "NUMERICAL_PII": 0.5674
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_1",
#     "text": "146382",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.8547,
#       "NUMERICAL_PII": 0.6731
#     }
#   },
#   {
#     "processed_text": "NAME_GIVEN_1",
#     "text": "Dharmadaas",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 14
#     },
#     "best_label": "NAME_GIVEN",
#     "labels": {
#       "NAME": 0.9909,
#       "NAME_GIVEN": 0.5818,
#       "NAME_FAMILY": 0.5289
#     }
#   },
#   {
#     "processed_text": "GENDER_SEXUALITY_1",
#     "text": "Male",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 4,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 20
#     },
#     "best_label": "GENDER_SEXUALITY",
#     "labels": {
#       "GENDER_SEXUALITY": 0.9973
#     }
#   },
#   {
#     "processed_text": "DOB_1",
#     "text": "1964-04-29",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 7
#     },
#     "best_label": "DOB",
#     "labels": {
#       "DOB": 0.9976
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_1",
#     "text": "+91 6345482027",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 14,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 16
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.997
#     }
#   },
#   {
#     "processed_text": "CONDITION_1",
#     "text": "Anthrax",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 7,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 13
#     },
#     "best_label": "CONDITION",
#     "labels": {
#       "CONDITION": 0.9899
#     }
#   },
#   {
#     "processed_text": "LOCATION_CITY_1",
#     "text": "Bhalswa Jahangir Pur",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 20,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "LOCATION_CITY",
#     "labels": {
#       "LOCATION": 0.841,
#       "LOCATION_CITY": 0.7836
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_2",
#     "text": "H1019",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.9693,
#       "NUMERICAL_PII": 0.4602
#     }
#   },
#   {
#     "processed_text": "NUMERICAL_PII_1",
#     "text": "132748",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "NUMERICAL_PII",
#     "labels": {
#       "NUMERICAL_PII": 0.7532,
#       "HEALTHCARE_NUMBER": 0.7515
#     }
#   },
#   {
#     "processed_text": "NAME_GIVEN_1",
#     "text": "Brahmvir",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 8,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 14
#     },
#     "best_label": "NAME_GIVEN",
#     "labels": {
#       "NAME": 0.9939,
#       "NAME_GIVEN": 0.9018,
#       "NAME_FAMILY": 0.0705
#     }
#   },
#   {
#     "processed_text": "GENDER_SEXUALITY_1",
#     "text": "Male",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 4,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 20
#     },
#     "best_label": "GENDER_SEXUALITY",
#     "labels": {
#       "GENDER_SEXUALITY": 0.9974
#     }
#   },
#   {
#     "processed_text": "DOB_1",
#     "text": "1991-11-11",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 7
#     },
#     "best_label": "DOB",
#     "labels": {
#       "DOB": 0.9984
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_1",
#     "text": "+91 7316972612",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 14,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 16
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.9963
#     }
#   },
#   {
#     "processed_text": "CONDITION_1",
#     "text": "Cystic fibrosis",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 15,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 13
#     },
#     "best_label": "CONDITION",
#     "labels": {
#       "CONDITION": 0.9967
#     }
#   },
#   {
#     "processed_text": "LOCATION_CITY_1",
#     "text": "Ambala",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "LOCATION_CITY",
#     "labels": {
#       "LOCATION": 0.9939,
#       "LOCATION_CITY": 0.9921
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_1",
#     "text": "H1018",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.9888
#     }
#   },
#   {
#     "processed_text": "NUMERICAL_PII_1",
#     "text": "167340",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "NUMERICAL_PII",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.7889,
#       "NUMERICAL_PII": 0.811
#     }
#   },
#   {
#     "processed_text": "GENDER_SEXUALITY_1",
#     "text": "Female",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 20
#     },
#     "best_label": "GENDER_SEXUALITY",
#     "labels": {
#       "GENDER_SEXUALITY": 0.9951
#     }
#   },
#   {
#     "processed_text": "DOB_1",
#     "text": "1981-01-25",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 7
#     },
#     "best_label": "DOB",
#     "labels": {
#       "DOB": 0.9981
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_1",
#     "text": "+91 2960004518",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 14,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 16
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.997
#     }
#   },
#   {
#     "processed_text": "CONDITION_1",
#     "text": "Galactosemia",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 12,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 13
#     },
#     "best_label": "CONDITION",
#     "labels": {
#       "CONDITION": 0.9976
#     }
#   },
#   {
#     "processed_text": "LOCATION_1",
#     "text": "Surendranagar Dudhrej",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 21,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 12
#     },
#     "best_label": "LOCATION",
#     "labels": {
#       "LOCATION": 0.8724,
#       "LOCATION_CITY": 0.6361,
#       "ORGANIZATION": 0.115,
#       "ORGANIZATION_MEDICAL_FACILITY": 0.0263
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_1",
#     "text": "H1003",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.9908,
#       "NUMERICAL_PII": 0.0669
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_1",
#     "text": "135184",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.9426,
#       "NUMERICAL_PII": 0.4727
#     }
#   },
#   {
#     "processed_text": "NAME_GIVEN_1",
#     "text": "Bhagvan",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 7,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 14
#     },
#     "best_label": "NAME_GIVEN",
#     "labels": {
#       "NAME": 0.9946,
#       "NAME_GIVEN": 0.8272,
#       "NAME_FAMILY": 0.3432
#     }
#   },
#   {
#     "processed_text": "GENDER_SEXUALITY_1",
#     "text": "Female",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 20
#     },
#     "best_label": "GENDER_SEXUALITY",
#     "labels": {
#       "GENDER_SEXUALITY": 0.9971
#     }
#   },
#   {
#     "processed_text": "DOB_1",
#     "text": "1966-07-24",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 7
#     },
#     "best_label": "DOB",
#     "labels": {
#       "DOB": 0.9982
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_1",
#     "text": "+91 0297693485",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 14,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 16
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.9967
#     }
#   },
#   {
#     "processed_text": "CONDITION_1",
#     "text": "Dengue",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 13
#     },
#     "best_label": "CONDITION",
#     "labels": {
#       "CONDITION": 0.9977
#     }
#   },
#   {
#     "processed_text": "LOCATION_CITY_1",
#     "text": "Bhimavaram",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "LOCATION_CITY",
#     "labels": {
#       "LOCATION_CITY": 0.9983,
#       "LOCATION": 0.9919
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_2",
#     "text": "H1018",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.9739,
#       "NUMERICAL_PII": 0.2418
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_1",
#     "text": "179662",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.7862,
#       "NUMERICAL_PII": 0.7288
#     }
#   },
#   {
#     "processed_text": "NAME_GIVEN_1",
#     "text": "Amritkala",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 9,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 14
#     },
#     "best_label": "NAME_GIVEN",
#     "labels": {
#       "NAME": 0.9957,
#       "NAME_GIVEN": 0.835,
#       "NAME_FAMILY": 0.2141
#     }
#   },
#   {
#     "processed_text": "GENDER_SEXUALITY_1",
#     "text": "Female",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 20
#     },
#     "best_label": "GENDER_SEXUALITY",
#     "labels": {
#       "GENDER_SEXUALITY": 0.9973
#     }
#   },
#   {
#     "processed_text": "DOB_1",
#     "text": "1933-11-20",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 7
#     },
#     "best_label": "DOB",
#     "labels": {
#       "DOB": 0.9984
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_1",
#     "text": "+91 0537157280",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 14,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 16
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.9967
#     }
#   },
#   {
#     "processed_text": "CONDITION_1",
#     "text": "Smallpox",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 8,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 13
#     },
#     "best_label": "CONDITION",
#     "labels": {
#       "CONDITION": 0.9976
#     }
#   },
#   {
#     "processed_text": "LOCATION_CITY_1",
#     "text": "Meerut",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "LOCATION_CITY",
#     "labels": {
#       "LOCATION": 0.9939,
#       "LOCATION_CITY": 0.9939
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_2",
#     "text": "H1018",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.9846,
#       "NUMERICAL_PII": 0.2394
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_1",
#     "text": "184479",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.9307,
#       "NUMERICAL_PII": 0.6162
#     }
#   },
#   {
#     "processed_text": "NAME_GIVEN_1",
#     "text": "Bandhu",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 14
#     },
#     "best_label": "NAME_GIVEN",
#     "labels": {
#       "NAME": 0.9952,
#       "NAME_GIVEN": 0.9454
#     }
#   },
#   {
#     "processed_text": "GENDER_SEXUALITY_1",
#     "text": "Male",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 4,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 20
#     },
#     "best_label": "GENDER_SEXUALITY",
#     "labels": {
#       "GENDER_SEXUALITY": 0.9972
#     }
#   },
#   {
#     "processed_text": "DOB_1",
#     "text": "1996-10-15",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 7
#     },
#     "best_label": "DOB",
#     "labels": {
#       "DOB": 0.9981
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_1",
#     "text": "+91 0695289163",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 14,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 16
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.9967
#     }
#   },
#   {
#     "processed_text": "CONDITION_1",
#     "text": "Pollen allergy",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 14,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 13
#     },
#     "best_label": "CONDITION",
#     "labels": {
#       "CONDITION": 0.9973
#     }
#   },
#   {
#     "processed_text": "LOCATION_CITY_1",
#     "text": "Chinsurah",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 9,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "LOCATION_CITY",
#     "labels": {
#       "LOCATION": 0.9945,
#       "LOCATION_CITY": 0.9874
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_2",
#     "text": "H1010",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.9884,
#       "NUMERICAL_PII": 0.0687
#     }
#   },
#   {
#     "processed_text": "NUMERICAL_PII_1",
#     "text": "156988",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "NUMERICAL_PII",
#     "labels": {
#       "NUMERICAL_PII": 0.9603,
#       "HEALTHCARE_NUMBER": 0.4293
#     }
#   },
#   {
#     "processed_text": "NAME_GIVEN_1",
#     "text": "Bhagavaana",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 14
#     },
#     "best_label": "NAME_GIVEN",
#     "labels": {
#       "NAME": 0.9945,
#       "NAME_GIVEN": 0.743,
#       "NAME_FAMILY": 0.3038
#     }
#   },
#   {
#     "processed_text": "GENDER_SEXUALITY_1",
#     "text": "Female",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 20
#     },
#     "best_label": "GENDER_SEXUALITY",
#     "labels": {
#       "GENDER_SEXUALITY": 0.9975
#     }
#   },
#   {
#     "processed_text": "DOB_1",
#     "text": "1935-09-16",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 7
#     },
#     "best_label": "DOB",
#     "labels": {
#       "DOB": 0.9984
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_1",
#     "text": "+91 6071745855",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 14,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 16
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.9969
#     }
#   },
#   {
#     "processed_text": "CONDITION_1",
#     "text": "Breast cancer",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 13,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 13
#     },
#     "best_label": "CONDITION",
#     "labels": {
#       "CONDITION": 0.9982
#     }
#   },
#   {
#     "processed_text": "LOCATION_CITY_1",
#     "text": "Shahjahanpur",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 12,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "LOCATION_CITY",
#     "labels": {
#       "LOCATION": 0.9942,
#       "LOCATION_CITY": 0.9954
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_1",
#     "text": "H1012",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.9896,
#       "NUMERICAL_PII": 0.1102
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_1",
#     "text": "132870",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.8456,
#       "NUMERICAL_PII": 0.7494
#     }
#   },
#   {
#     "processed_text": "GENDER_SEXUALITY_1",
#     "text": "Female",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 20
#     },
#     "best_label": "GENDER_SEXUALITY",
#     "labels": {
#       "GENDER_SEXUALITY": 0.9913
#     }
#   },
#   {
#     "processed_text": "DOB_1",
#     "text": "1924-11-09",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 7
#     },
#     "best_label": "DOB",
#     "labels": {
#       "DOB": 0.9985
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_1",
#     "text": "+91 8906694405",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 14,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 16
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.9971
#     }
#   },
#   {
#     "processed_text": "CONDITION_1",
#     "text": "Glaucoma",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 8,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 13
#     },
#     "best_label": "CONDITION",
#     "labels": {
#       "CONDITION": 0.9973
#     }
#   },
#   {
#     "processed_text": "LOCATION_CITY_1",
#     "text": "Jabalpur",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 8,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "LOCATION_CITY",
#     "labels": {
#       "LOCATION": 0.9946,
#       "LOCATION_CITY": 0.9959
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_2",
#     "text": "H1017",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.9932,
#       "NUMERICAL_PII": 0.0556
#     }
#   },
#   {
#     "processed_text": "NUMERICAL_PII_1",
#     "text": "148137",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "NUMERICAL_PII",
#     "labels": {
#       "NUMERICAL_PII": 0.9248,
#       "HEALTHCARE_NUMBER": 0.3824
#     }
#   },
#   {
#     "processed_text": "NAME_GIVEN_1",
#     "text": "Umang",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 14
#     },
#     "best_label": "NAME_GIVEN",
#     "labels": {
#       "NAME": 0.9934,
#       "NAME_GIVEN": 0.9408
#     }
#   },
#   {
#     "processed_text": "GENDER_SEXUALITY_1",
#     "text": "Female",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 20
#     },
#     "best_label": "GENDER_SEXUALITY",
#     "labels": {
#       "GENDER_SEXUALITY": 0.9971
#     }
#   },
#   {
#     "processed_text": "DOB_1",
#     "text": "1963-07-14",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 7
#     },
#     "best_label": "DOB",
#     "labels": {
#       "DOB": 0.9982
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_1",
#     "text": "+91 9485838770",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 14,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 16
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.9968
#     }
#   },
#   {
#     "processed_text": "CONDITION_1",
#     "text": "Pet allergy",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 11,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 13
#     },
#     "best_label": "CONDITION",
#     "labels": {
#       "CONDITION": 0.9978
#     }
#   },
#   {
#     "processed_text": "LOCATION_CITY_1",
#     "text": "Haridwar",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 8,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "LOCATION_CITY",
#     "labels": {
#       "LOCATION": 0.9943,
#       "LOCATION_CITY": 0.9971
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_1",
#     "text": "H1002",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.9862,
# ...
#       "end_idx": 8,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "LOCATION_CITY",
#     "labels": {
#       "LOCATION": 0.9942,
#       "LOCATION_CITY": 0.9912
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_1",
#     "text": "H1017",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.9928
#     }
#   },
#   {
#     "processed_text": "NUMERICAL_PII_1",
#     "text": "115143",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "NUMERICAL_PII",
#     "labels": {
#       "NUMERICAL_PII": 0.8603,
#       "HEALTHCARE_NUMBER": 0.6958
#     }
#   },
#   {
#     "processed_text": "NAME_GIVEN_1",
#     "text": "Anshuk",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 14
#     },
#     "best_label": "NAME_GIVEN",
#     "labels": {
#       "NAME": 0.9946,
#       "NAME_GIVEN": 0.9684
#     }
#   },
#   {
#     "processed_text": "GENDER_SEXUALITY_1",
#     "text": "Male",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 4,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 20
#     },
#     "best_label": "GENDER_SEXUALITY",
#     "labels": {
#       "GENDER_SEXUALITY": 0.9955
#     }
#   },
#   {
#     "processed_text": "DOB_1",
#     "text": "1991-06-17",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 7
#     },
#     "best_label": "DOB",
#     "labels": {
#       "DOB": 0.9982
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_1",
#     "text": "+91 9764690642",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 14,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 16
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.9974
#     }
#   },
#   {
#     "processed_text": "LOCATION_CITY_1",
#     "text": "Uluberia",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 8,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "LOCATION_CITY",
#     "labels": {
#       "LOCATION": 0.9947,
#       "LOCATION_CITY": 0.9885
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_1",
#     "text": "H1001",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.982,
#       "NUMERICAL_PII": 0.2009
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_1",
#     "text": "156364",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.8789,
#       "NUMERICAL_PII": 0.7019
#     }
#   },
#   {
#     "processed_text": "GENDER_SEXUALITY_1",
#     "text": "Male",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 4,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 20
#     },
#     "best_label": "GENDER_SEXUALITY",
#     "labels": {
#       "GENDER_SEXUALITY": 0.9949
#     }
#   },
#   {
#     "processed_text": "DOB_1",
#     "text": "1994-01-13",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 7
#     },
#     "best_label": "DOB",
#     "labels": {
#       "DOB": 0.9981
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_1",
#     "text": "+91 8444537013",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 14,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 16
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.9968
#     }
#   },
#   {
#     "processed_text": "CONDITION_1",
#     "text": "Cholera",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 7,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 13
#     },
#     "best_label": "CONDITION",
#     "labels": {
#       "CONDITION": 0.9988
#     }
#   },
#   {
#     "processed_text": "LOCATION_CITY_1",
#     "text": "Panihati",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 8,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "LOCATION_CITY",
#     "labels": {
#       "LOCATION": 0.9943,
#       "LOCATION_CITY": 0.9924
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_2",
#     "text": "H1019",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.9348,
#       "NUMERICAL_PII": 0.5168
#     }
#   },
#   {
#     "processed_text": "NUMERICAL_PII_1",
#     "text": "191132",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "NUMERICAL_PII",
#     "labels": {
#       "NUMERICAL_PII": 0.9414,
#       "HEALTHCARE_NUMBER": 0.4368
#     }
#   },
#   {
#     "processed_text": "NAME_GIVEN_1",
#     "text": "Dipesh",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 14
#     },
#     "best_label": "NAME_GIVEN",
#     "labels": {
#       "NAME": 0.9895,
#       "NAME_GIVEN": 0.8567,
#       "NAME_FAMILY": 0.1331
#     }
#   },
#   {
#     "processed_text": "GENDER_SEXUALITY_1",
#     "text": "Female",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 20
#     },
#     "best_label": "GENDER_SEXUALITY",
#     "labels": {
#       "GENDER_SEXUALITY": 0.9969
#     }
#   },
#   {
#     "processed_text": "DOB_1",
#     "text": "1949-04-01",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 7
#     },
#     "best_label": "DOB",
#     "labels": {
#       "DOB": 0.998
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_1",
#     "text": "+91 5851958964",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 14,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 16
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.9966
#     }
#   },
#   {
#     "processed_text": "CONDITION_1",
#     "text": "Glaucoma",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 8,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 13
#     },
#     "best_label": "CONDITION",
#     "labels": {
#       "CONDITION": 0.9972
#     }
#   },
#   {
#     "processed_text": "LOCATION_CITY_1",
#     "text": "Kochi",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "LOCATION_CITY",
#     "labels": {
#       "LOCATION_CITY": 0.9977,
#       "LOCATION": 0.993
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_1",
#     "text": "H1016",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.9856,
#       "NUMERICAL_PII": 0.2458
#     }
#   },
#   {
#     "processed_text": "NUMERICAL_PII_1",
#     "text": "105686",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "NUMERICAL_PII",
#     "labels": {
#       "NUMERICAL_PII": 0.9507,
#       "HEALTHCARE_NUMBER": 0.4147
#     }
#   },
#   {
#     "processed_text": "GENDER_SEXUALITY_1",
#     "text": "Male",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 4,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 20
#     },
#     "best_label": "GENDER_SEXUALITY",
#     "labels": {
#       "GENDER_SEXUALITY": 0.9957
#     }
#   },
#   {
#     "processed_text": "DOB_1",
#     "text": "1930-09-01",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 7
#     },
#     "best_label": "DOB",
#     "labels": {
#       "DOB": 0.9984
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_1",
#     "text": "+91 7061843400",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 14,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 16
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.9965
#     }
#   },
#   {
#     "processed_text": "CONDITION_1",
#     "text": "Hepatitis",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 9,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 13
#     },
#     "best_label": "CONDITION",
#     "labels": {
#       "CONDITION": 0.9974
#     }
#   },
#   {
#     "processed_text": "LOCATION_CITY_1",
#     "text": "Kolhapur",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 8,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "LOCATION_CITY",
#     "labels": {
#       "LOCATION": 0.9943,
#       "LOCATION_CITY": 0.9962
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_1",
#     "text": "H1008",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.9763,
#       "NUMERICAL_PII": 0.3761
#     }
#   },
#   {
#     "processed_text": "NUMERICAL_PII_1",
#     "text": "160140",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "NUMERICAL_PII",
#     "labels": {
#       "NUMERICAL_PII": 0.8637,
#       "HEALTHCARE_NUMBER": 0.7683
#     }
#   },
#   {
#     "processed_text": "NAME_GIVEN_1",
#     "text": "Kishan",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 14
#     },
#     "best_label": "NAME_GIVEN",
#     "labels": {
#       "NAME": 0.996,
#       "NAME_GIVEN": 0.971
#     }
#   },
#   {
#     "processed_text": "GENDER_SEXUALITY_1",
#     "text": "Male",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 4,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 20
#     },
#     "best_label": "GENDER_SEXUALITY",
#     "labels": {
#       "GENDER_SEXUALITY": 0.9965
#     }
#   },
#   {
#     "processed_text": "DOB_1",
#     "text": "1923-05-12",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 7
#     },
#     "best_label": "DOB",
#     "labels": {
#       "DOB": 0.9984
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_1",
#     "text": "+91 9067652693",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 14,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 16
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.9969
#     }
#   },
#   {
#     "processed_text": "CONDITION_1",
#     "text": "Rett Syndrome",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 13,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 13
#     },
#     "best_label": "CONDITION",
#     "labels": {
#       "CONDITION": 0.9979
#     }
#   },
#   {
#     "processed_text": "LOCATION_CITY_1",
#     "text": "Srikakulam",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "LOCATION_CITY",
#     "labels": {
#       "LOCATION_CITY": 0.9979,
#       "LOCATION": 0.9934
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_1",
#     "text": "H1002",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.9742,
#       "NUMERICAL_PII": 0.4019
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_1",
#     "text": "114252",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.8803,
#       "NUMERICAL_PII": 0.671
#     }
#   },
#   {
#     "processed_text": "GENDER_SEXUALITY_1",
#     "text": "Female",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 20
#     },
#     "best_label": "GENDER_SEXUALITY",
#     "labels": {
#       "GENDER_SEXUALITY": 0.9951
#     }
#   },
#   {
#     "processed_text": "DOB_1",
#     "text": "1927-02-26",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 7
#     },
#     "best_label": "DOB",
#     "labels": {
#       "DOB": 0.9982
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_1",
#     "text": "+91 4984346995",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 14,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 16
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.9965
#     }
#   },
#   {
#     "processed_text": "CONDITION_1",
#     "text": "Diabetes",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 8,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 13
#     },
#     "best_label": "CONDITION",
#     "labels": {
#       "CONDITION": 0.9982
#     }
#   },
#   {
#     "processed_text": "LOCATION_CITY_1",
#     "text": "Ambarnath",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 9,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "LOCATION_CITY",
#     "labels": {
#       "LOCATION": 0.9905,
#       "LOCATION_CITY": 0.9847
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_2",
#     "text": "H1014",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.9843,
#       "NUMERICAL_PII": 0.2071
#     }
#   },
#   {
#     "processed_text": "NUMERICAL_PII_1",
#     "text": "188365",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 6,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "NUMERICAL_PII",
#     "labels": {
#       "NUMERICAL_PII": 0.9482,
#       "HEALTHCARE_NUMBER": 0.3298
#     }
#   },
#   {
#     "processed_text": "NAME_GIVEN_1",
#     "text": "Bhageeratha",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 11,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 14
#     },
#     "best_label": "NAME_GIVEN",
#     "labels": {
#       "NAME": 0.9959,
#       "NAME_GIVEN": 0.9353,
#       "NAME_FAMILY": 0.0561
#     }
#   },
#   {
#     "processed_text": "GENDER_SEXUALITY_1",
#     "text": "Male",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 4,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 20
#     },
#     "best_label": "GENDER_SEXUALITY",
#     "labels": {
#       "GENDER_SEXUALITY": 0.9968
#     }
#   },
#   {
#     "processed_text": "DOB_1",
#     "text": "1973-03-21",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 10,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 7
#     },
#     "best_label": "DOB",
#     "labels": {
#       "DOB": 0.9982
#     }
#   },
#   {
#     "processed_text": "PHONE_NUMBER_1",
#     "text": "+91 0590662722",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 14,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 16
#     },
#     "best_label": "PHONE_NUMBER",
#     "labels": {
#       "PHONE_NUMBER": 0.997
#     }
#   },
#   {
#     "processed_text": "CONDITION_1",
#     "text": "Pet allergy",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 11,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 13
#     },
#     "best_label": "CONDITION",
#     "labels": {
#       "CONDITION": 0.9982
#     }
#   },
#   {
#     "processed_text": "LOCATION_CITY_1",
#     "text": "Sonipat",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 7,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 17
#     },
#     "best_label": "LOCATION_CITY",
#     "labels": {
#       "LOCATION": 0.9944,
#       "LOCATION_CITY": 0.994
#     }
#   },
#   {
#     "processed_text": "HEALTHCARE_NUMBER_1",
#     "text": "H1017",
#     "location": {
#       "stt_idx": 0,
#       "end_idx": 5,
#       "stt_idx_processed": 0,
#       "end_idx_processed": 21
#     },
#     "best_label": "HEALTHCARE_NUMBER",
#     "labels": {
#       "HEALTHCARE_NUMBER": 0.9836,
#       "NUMERICAL_PII": 0.3765
#     }
#   }
# ]
